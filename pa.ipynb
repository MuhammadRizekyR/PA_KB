# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
import os
import shutil
import random
from PIL import Image

# %%
root_path = r'D:\folder kiki\kuliah semester 5\praktikum KB\pa'
source_path = os.path.join(root_path, 'dataset_padang_food')
destination = os.path.join(root_path, 'data_tvt')
use_path = os.path.join(root_path, 'padang_food_clean')

# %%
#Data Preprocessing

# %%
# make folder
if (os.path.isdir(os.path.join(root_path, 'padang_food_clean'))):
    print(f"path {os.path.join(root_path, 'padang_food_clean')} sudah ada")
else:
    os.makedirs(os.path.join(root_path, 'padang_food_clean'))
    for folder in folders.keys():
        os.makedirs(os.path.join(root_path, f'padang_food_clean/{folder}'))
        

# #resize image
    
for folder in os.listdir(source_path):
    for files in os.listdir(os.path.join(source_path, folder)):
        img1 = Image.open(os.path.join(source_path,f"{folder}/{files}"))
        img2 = img1.convert('RGB')
        imgResize = img2.resize((128, 128))
        imgResize.save(os.path.join(root_path, 'padang_food_clean',f"{folder}/{files}") + files[:] +'.jpg', quality = 100)
# Out:
# path D:\folder kiki\kuliah semester 5\praktikum KB\pa\padang_food_clean sudah ada

# %%
# make folder
if (os.path.isdir(os.path.join(root_path, 'data_tvt'))):
    print(f"path {os.path.join(root_path, 'data_tvt')} sudah ada")
else:
    os.makedirs(os.path.join(root_path, 'data_tvt'))
    # for folder in folders.keys():
    #     os.makedirs(os.path.join(root_path, f'data_tvt/{folder}'))

# %%
folders = {}

for folder in os.listdir(use_path):
    folders[folder] = os.listdir(os.path.join(use_path, folder))

# %%
#show image
fig = plt.figure(figsize = (30,10))

image_position = 0

for index, folder in enumerate(folders.keys()):
    for j in range(1):
        image_position += 1
        # Adds a subplot at the 1st position
        fig.add_subplot(2, 5, image_position)
        plt.imshow(img.imread(os.path.join(use_path, folder, folders[folder][random.randint(0,100)])))
        plt.title(folder)

# %%
# visualization
plt.figure(figsize = (20,20))
plt.title('PADANG FOOD', fontweight='bold')
plt.xlabel('Makanan', fontstyle='oblique')
plt.ylabel('Jumlah', fontstyle='oblique')
plt.bar(folders.keys(),
        [len(data) for data in folders.values()],
        color=['#B3541E', '#F9E4D4', '#541212', '#362222', '#FFCE45','#FFCC1D','#D4AC2B','#AA2B1D','#F5DD7B'])

for index, value in enumerate([len(data) for data in folders.values()]):
    plt.text(index - .1, value + 2, str(value))

plt.show()

# %%
if (os.path.isdir(os.path.join(destination, 'training'))):
    print(f"path {os.path.join(destination, 'training')} sudah ada")
else:
    os.makedirs(os.path.join(destination, 'training'))
    for folder in folders.keys():
        os.makedirs(os.path.join(destination, f'training/{folder}'))

if (os.path.isdir(os.path.join(destination, 'validation'))):
    print(f"path {os.path.join(destination, 'validation')} sudah ada")
else:
    os.makedirs(os.path.join(destination, 'validation'))
    for folder in folders.keys():
        os.makedirs(os.path.join(destination, f'validation/{folder}'))
        
if (os.path.isdir(os.path.join(destination, 'testing'))):
    print(f"path {os.path.join(destination, 'testing')} sudah ada")
else:
    os.makedirs(os.path.join(destination, 'testing'))
    for folder in folders.keys():
        os.makedirs(os.path.join(destination, f'testing/{folder}'))

# %%
# def functvt (nama):
#     if (os.path.isdir(os.path.join(destination, nama))):
#         print(f"path {os.path.join(destination, nama)} sudah ada")
#     else:
#         os.makedirs(os.path.join(destination, nama))
#         for folder in folders.keys():
#             os.makedirs(os.path.join(destination, f'(nama)/{folder}'))

# %%
files = {
    "ayam_goreng" : [],
    "ayam_pop" : [],
    "daging_rendang" : [],
    "dendeng_batokok" : [],
    "gulai_ikan" : [],
    "gulai_tambusu" : [],
    "gulai_tunjang" : [],
    "telur_balado" : [],
    "telur_dadar" : [],
}

for folder in files.keys():
    for file in os.listdir(os.path.join(use_path, folder)):
        if (os.path.getsize(os.path.join(use_path, f"{folder}/{file}"))):
            files[folder].append(file)
        else:
            print(f'file {file} dilewati saja')

# %%
for folder in files.keys():
    files[folder] = random.sample(files[folder], len(files[folder]))
    
file_training = {
    "ayam_goreng" : [],
    "ayam_pop" : [],
    "daging_rendang" : [],
    "dendeng_batokok" : [],
    "gulai_ikan" : [],
    "gulai_tambusu" : [],
    "gulai_tunjang" : [],
    "telur_balado" : [],
    "telur_dadar" : [],
}

file_validation = {
    "ayam_goreng" : [],
    "ayam_pop" : [],
    "daging_rendang" : [],
    "dendeng_batokok" : [],
    "gulai_ikan" : [],
    "gulai_tambusu" : [],
    "gulai_tunjang" : [],
    "telur_balado" : [],
    "telur_dadar" : [],
}

file_testing = {
    "ayam_goreng" : [],
    "ayam_pop" : [],
    "daging_rendang" : [],
    "dendeng_batokok" : [],
    "gulai_ikan" : [],
    "gulai_tambusu" : [],
    "gulai_tunjang" : [],
    "telur_balado" : [],
    "telur_dadar" : [],
}

# %%
for folder in file_training.keys():
    file_training[folder] = files[folder][:-20]
    
for folder in file_validation.keys():
    file_validation[folder] = files[folder][-20:-10]
    
for folder in file_testing.keys():
    file_testing[folder] = files[folder][-10:]
    
len(file_training['ayam_goreng'])
# Out:
# 87

# %%
# len(file_validation['ayam_goreng'])

# %%
# len(file_testing['ayam_goreng'])

# %%
for folder in file_training.keys():
    for file in file_training[folder]:
        shutil.copyfile(
            os.path.join(use_path, f'{folder}/{file}'),
            os.path.join(destination, f'training/{folder}/{file}')
        )
    for file in file_validation[folder]:
        shutil.copyfile(
            os.path.join(use_path, f'{folder}/{file}'),
            os.path.join(destination, f'validation/{folder}/{file}')
        )
    for file in file_testing[folder]:
        shutil.copyfile(
            os.path.join(use_path, f'{folder}/{file}'),
            os.path.join(destination, f'testing/{folder}/{file}')
        )

# %%
folders[folder]
# Out:
# ['telur_dadar (1).jpgtelur_dadar (1).jpg.jpg',
#  'telur_dadar (10).jpgtelur_dadar (10).jpg.jpg',
#  'telur_dadar (100).jpgtelur_dadar (100).jpg.jpg',
#  'telur_dadar (101).jpgtelur_dadar (101).jpg.jpg',
#  'telur_dadar (102).jpgtelur_dadar (102).jpg.jpg',
#  'telur_dadar (103).jpgtelur_dadar (103).jpg.jpg',
#  'telur_dadar (104).jpgtelur_dadar (104).jpg.jpg',
#  'telur_dadar (105).jpgtelur_dadar (105).jpg.jpg',
#  'telur_dadar (106).jpgtelur_dadar (106).jpg.jpg',
#  'telur_dadar (107).jpgtelur_dadar (107).jpg.jpg',
#  'telur_dadar (108).jpgtelur_dadar (108).jpg.jpg',
#  'telur_dadar (109).JPGtelur_dadar (109).JPG.jpg',
#  'telur_dadar (11).jpgtelur_dadar (11).jpg.jpg',
#  'telur_dadar (110).jpgtelur_dadar (110).jpg.jpg',
#  'telur_dadar (111).jpgtelur_dadar (111).jpg.jpg',
#  'telur_dadar (114).jpgtelur_dadar (114).jpg.jpg',
#  'telur_dadar (115).jpgtelur_dadar (115).jpg.jpg',
#  'telur_dadar (117).jpgtelur_dadar (117).jpg.jpg',
#  'telur_dadar (118).JPGtelur_dadar (118).JPG.jpg',
#  'telur_dadar (119).jpgtelur_dadar (119).jpg.jpg',
#  'telur_dadar (12).jpgtelur_dadar (12).jpg.jpg',
#  'telur_dadar (120).jpgtelur_dadar (120).jpg.jpg',
#  'telur_dadar (121).jpgtelur_dadar (121).jpg.jpg',
#  'telur_dadar (122).jpgtelur_dadar (122).jpg.jpg',
#  'telur_dadar (123).jpgtelur_dadar (123).jpg.jpg',
#  'telur_dadar (13).jpgtelur_dadar (13).jpg.jpg',
#  'telur_dadar (14).jpgtelur_dadar (14).jpg.jpg',
#  'telur_dadar (16).jpgtelur_dadar (16).jpg.jpg',
#  'telur_dadar (17).jpgtelur_dadar (17).jpg.jpg',
#  'telur_dadar (18).jpgtelur_dadar (18).jpg.jpg',
#  'telur_dadar (19).jpgtelur_dadar (19).jpg.jpg',
#  'telur_dadar (2).jpgtelur_dadar (2).jpg.jpg',
#  'telur_dadar (20).jpgtelur_dadar (20).jpg.jpg',
#  'telur_dadar (21).jpgtelur_dadar (21).jpg.jpg',
#  'telur_dadar (22).jpgtelur_dadar (22).jpg.jpg',
#  'telur_dadar (23).jpgtelur_dadar (23).jpg.jpg',
#  'telur_dadar (25).jpgtelur_dadar (25).jpg.jpg',
#  'telur_dadar (26).jpgtelur_dadar (26).jpg.jpg',
#  'telur_dadar (27).jpgtelur_dadar (27).jpg.jpg',
#  'telur_dadar (28).jpgtelur_dadar (28).jpg.jpg',
#  'telur_dadar (29).jpgtelur_dadar (29).jpg.jpg',
#  'telur_dadar (3).jpgtelur_dadar (3).jpg.jpg',
#  'telur_dadar (30).jpgtelur_dadar (30).jpg.jpg',
#  'telur_dadar (31).jpgtelur_dadar (31).jpg.jpg',
#  'telur_dadar (32).jpgtelur_dadar (32).jpg.jpg',
#  'telur_dadar (33).jpgtelur_dadar (33).jpg.jpg',
#  'telur_dadar (34).jpgtelur_dadar (34).jpg.jpg',
#  'telur_dadar (35).jpgtelur_dadar (35).jpg.jpg',
#  'telur_dadar (36).jpgtelur_dadar (36).jpg.jpg',
#  'telur_dadar (37).jpgtelur_dadar (37).jpg.jpg',
#  'telur_dadar (38).jpgtelur_dadar (38).jpg.jpg',
#  'telur_dadar (39).jpgtelur_dadar (39).jpg.jpg',
#  'telur_dadar (4).jpgtelur_dadar (4).jpg.jpg',
#  'telur_dadar (40).jpgtelur_dadar (40).jpg.jpg',
#  'telur_dadar (41).jpgtelur_dadar (41).jpg.jpg',
#  'telur_dadar (42).jpgtelur_dadar (42).jpg.jpg',
#  'telur_dadar (43).jpgtelur_dadar (43).jpg.jpg',
#  'telur_dadar (44).jpgtelur_dadar (44).jpg.jpg',
#  'telur_dadar (45).jpgtelur_dadar (45).jpg.jpg',
#  'telur_dadar (46).jpgtelur_dadar (46).jpg.jpg',
#  'telur_dadar (47).jpgtelur_dadar (47).jpg.jpg',
#  'telur_dadar (48).jpgtelur_dadar (48).jpg.jpg',
#  'telur_dadar (49).jpgtelur_dadar (49).jpg.jpg',
#  'telur_dadar (5).jpgtelur_dadar (5).jpg.jpg',
#  'telur_dadar (50).jpgtelur_dadar (50).jpg.jpg',
#  'telur_dadar (51).JPGtelur_dadar (51).JPG.jpg',
#  'telur_dadar (52).jpgtelur_dadar (52).jpg.jpg',
#  'telur_dadar (53).jpgtelur_dadar (53).jpg.jpg',
#  'telur_dadar (55).jpgtelur_dadar (55).jpg.jpg',
#  'telur_dadar (56).JPGtelur_dadar (56).JPG.jpg',
#  'telur_dadar (57).jpgtelur_dadar (57).jpg.jpg',
#  'telur_dadar (58).jpgtelur_dadar (58).jpg.jpg',
#  'telur_dadar (59).jpgtelur_dadar (59).jpg.jpg',
#  'telur_dadar (6).jpgtelur_dadar (6).jpg.jpg',
#  'telur_dadar (60).jpgtelur_dadar (60).jpg.jpg',
#  'telur_dadar (61).jpgtelur_dadar (61).jpg.jpg',
#  'telur_dadar (62).jpgtelur_dadar (62).jpg.jpg',
#  'telur_dadar (63).jpgtelur_dadar (63).jpg.jpg',
#  'telur_dadar (64).jpgtelur_dadar (64).jpg.jpg',
#  'telur_dadar (65).jpgtelur_dadar (65).jpg.jpg',
#  'telur_dadar (66).jpgtelur_dadar (66).jpg.jpg',
#  'telur_dadar (67).jpgtelur_dadar (67).jpg.jpg',
#  'telur_dadar (69).jpgtelur_dadar (69).jpg.jpg',
#  'telur_dadar (7).jpgtelur_dadar (7).jpg.jpg',
#  'telur_dadar (70).jpgtelur_dadar (70).jpg.jpg',
#  'telur_dadar (71).jpgtelur_dadar (71).jpg.jpg',
#  'telur_dadar (72).jpgtelur_dadar (72).jpg.jpg',
#  'telur_dadar (73).jpgtelur_dadar (73).jpg.jpg',
#  'telur_dadar (74).jpgtelur_dadar (74).jpg.jpg',
#  'telur_dadar (75).jpgtelur_dadar (75).jpg.jpg',
#  'telur_dadar (76).jpgtelur_dadar (76).jpg.jpg',
#  'telur_dadar (77).jpgtelur_dadar (77).jpg.jpg',
#  'telur_dadar (78).jpgtelur_dadar (78).jpg.jpg',
#  'telur_dadar (79).jpgtelur_dadar (79).jpg.jpg',
#  'telur_dadar (8).jpgtelur_dadar (8).jpg.jpg',
#  'telur_dadar (80).jpgtelur_dadar (80).jpg.jpg',
#  'telur_dadar (81).jpgtelur_dadar (81).jpg.jpg',
#  'telur_dadar (82).jpgtelur_dadar (82).jpg.jpg',
#  'telur_dadar (83).jpgtelur_dadar (83).jpg.jpg',
#  'telur_dadar (84).jpgtelur_dadar (84).jpg.jpg',
#  'telur_dadar (85).jpgtelur_dadar (85).jpg.jpg',
#  'telur_dadar (86).jpgtelur_dadar (86).jpg.jpg',
#  'telur_dadar (87).jpgtelur_dadar (87).jpg.jpg',
#  'telur_dadar (88).jpgtelur_dadar (88).jpg.jpg',
#  'telur_dadar (89).jpgtelur_dadar (89).jpg.jpg',
#  'telur_dadar (9).jpgtelur_dadar (9).jpg.jpg',
#  'telur_dadar (90).jpgtelur_dadar (90).jpg.jpg',
#  'telur_dadar (91).jpgtelur_dadar (91).jpg.jpg',
#  'telur_dadar (92).jpgtelur_dadar (92).jpg.jpg',
#  'telur_dadar (93).jpgtelur_dadar (93).jpg.jpg',
#  'telur_dadar (94).jpgtelur_dadar (94).jpg.jpg',
#  'telur_dadar (95).jpgtelur_dadar (95).jpg.jpg',
#  'telur_dadar (96).jpgtelur_dadar (96).jpg.jpg',
#  'telur_dadar (97).jpgtelur_dadar (97).jpg.jpg',
#  'telur_dadar (98).jpgtelur_dadar (98).jpg.jpg',
#  'telur_dadar (99).jpgtelur_dadar (99).jpg.jpg']

# %%
#Resize and Rescaling layer

# %%
# RR = tf.keras.Sequential([
#     tf.keras.layers.Resizing(225,225,crop_to_aspect_ratio=False),
#     tf.keras.layers.Rescaling(1./255)
# ])
